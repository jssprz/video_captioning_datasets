# %% [markdown]
# ## 2020 Readme
#
# TRECVID-VTT
#
# Video-to-text dataset
#
# This dataset contains short videos (ranging from 3 seconds to 10 seconds) from TRECVID VTT task from 2016 to 2019. There are 7485 videos with captions. Each video has between 2 and 5 captions, which have been written by dedicated annotators. The videos have IDs from 1 to 7485. The videos are given in the following format:
#
# 1. There are 6475 URLs from Twitter Vine. These URLs are in the vtt_video_urls.txt file. Each line in the file gives the Video ID followed by its URL.
# 2. There are 1010 video files available to download from our Flickr dataset. These videos are in the webm format and have the Creative Commons License.
# 3. The file vtt_ground_truth.txt contains the captions for all videos. Each line in the file gives the Video ID followed by its caption.
# 4. Videos with IDs from 1 to 3528 have between 2 to 5 captions. Videos from 3529 to 7485 have 5 captions each.
#
# If you use this dataset, please cite the following paper:
#
# @inproceedings{awad2019trecvid,
#   title={Trecvid 2019: An evaluation campaign to benchmark video activity detection, video captioning and matching, and video search \& retrieval},
#   author={Awad, George and Butt, Asad and Curtis, Keith and Lee, Yooyoung and Fiscus, Jonathan and Godil, Afzal and Delgado, Andrew and others},
#   year={2019}
# }

# %% [markdown]
# ## Generate corpus and gruond-truth references of released videos
#
# ### Corpus file contents
# 0. train_data: captions and idxs of training videos in format [corpus_widxs, vidxs, corpus_pidxs], where:
#     - corpus_widxs is a list of lists with the index of words in the vocabulary
#     - vidxs is a list of indexes of video features in the features file
#     - corpus_pidxs is a list of lists with the index of POS tags in the POS tagging vocabulary
# 1. val_data: same format of train_data. We created this set randomly sampling 20% of videos in the tv2020 released data for training.
# 2. test_data: **None**. The videos for testing have not been released yet.
# 3. vocabulary: in format {'word': count}.
# 4. idx2word: is the vocabulary in format {idx: 'word'}.
# 5. word_embeddings: are the vectors of each word. The i-th row is the word vector of the i-th word in the vocabulary.
# 6. idx2pos: is the vocabulary of POS tagging in format {idx: 'POSTAG'}

# %% [markdown]
# ### Generate split for training and validation

# %%
train_corpus = []
with open('../../../data/TRECVID/tv2020/train/vtt_ground_truth.txt') as f:
    vidxs, corpus = zip(*[l.strip().split(' ', 1) for l in f.readlines()])

print('count of videos: ', len(set(vidxs)))    
print('original count of pairs: ', len(vidxs))
    
## remove vids that has a video with problem
import os
videos_dir_path = '../../../data/TRECVID/tv2020/train/videos'
vidxs_to_delete = [int(filename[6:filename.index('.')]) for filename in os.listdir(videos_dir_path) if not os.path.getsize(os.path.join(videos_dir_path, filename))]

import random
unique_vidxs = set([int(vidx) for vidx in vidxs]) - set(vidxs_to_delete)
random.seed(42)
sampled_vidxs = random.sample(vidxs, len(unique_vidxs)//5) # 20% of videos for validation

train_vidxs, train_corpus = zip(*[(int(vidx)-1, corpus[i]) for (i, vidx) in enumerate(vidxs) if not vidx in sampled_vidxs])
valid_vidxs, valid_corpus = zip(*[(int(vidx)-1, corpus[i]) for (i, vidx) in enumerate(vidxs) if vidx in sampled_vidxs])

print('\nMy split:')
print('count of training pairs: ', len(train_vidxs))
print('count of validation pairs: ', len(valid_vidxs))
# Out:
# count of videos:  7485
# original count of pairs:  28183
#
# My split:
# count of training pairs:  22491
# count of validation pairs:  5692

# %% [markdown]
# ### Discard videos without features (video files that have problem)
# **IMPORTANT**: I don't need to remove the features of the .h5 file. I only need to remove the indices and captions from corpus.

# %%
import h5py
with h5py.File('../../../data/TRECVID/tv2020/features/features_linspace16_20-cnn_globals-cnn_sem_globals-cnn_features-c3d_features-eco_globals.h5', 'r+') as feats_file:
    dataset = feats_file['TRECVID-2020']
    print(dataset.keys())
    cnn_fts = dataset['cnn_features'][...]
    print(cnn_fts.shape)
    
import numpy as np
vidxs_to_discard = []
for i, v in enumerate(cnn_fts):
    if np.all(v == np.zeros((20,2048))):
        vidxs_to_discard.append(i)
print(len(vidxs_to_discard), ' videos to dicard')

train_vidxs, train_corpus = zip(*[(vidx, train_corpus[i]) for (i, vidx) in enumerate(train_vidxs) if not vidx in vidxs_to_discard])
valid_vidxs, valid_corpus = zip(*[(vidx, valid_corpus[i]) for (i, vidx) in enumerate(valid_vidxs) if not vidx in vidxs_to_discard])

print('count of training pairs: ', len(train_vidxs))
print('count of validation pairs: ', len(valid_vidxs))
# Out:
# <KeysViewHDF5 ['c3d_features', 'cnn_features', 'cnn_globals', 'cnn_sem_globals', 'count_features', 'eco_globals', 'frames_tstamp']>
# (7485, 20, 2048)
# 254  videos to dicard
# count of training pairs:  21956
# count of validation pairs:  5634

# %% [markdown]
# ### Get pretrained embeddings

# %%
import os
import numpy as np

wordvectors = {}
# with open('./glove.42B.300d.txt') as f:
with open('./glove.6B.300d.txt') as f:
    for line in f:
        s = line.strip().split(' ')
        if len(s) == 301:
            wordvectors[s[0]] = np.array(s[1:], dtype=float)
    print(len(wordvectors))
# Out:
# 400000

# %% [markdown]
# ### Determine the vocabulary from train split

# %%
import nltk
nltk.download('punkt')

vocab, total_len = {}, 0
for cap in train_corpus:
    tokens = nltk.word_tokenize(cap.lower())
    total_len += len(tokens)
    for w in tokens:
        try:
            vocab[w] += 1
        except:
            vocab[w] = 1

print('Avg. count of words per caption:', total_len/len(train_corpus))
print('Count of unique words: ', len(vocab))
            
to_del = []
for w in vocab.keys():
    if not w in wordvectors:
        to_del.append(w)
        print('missing word: {}'.format(w))

print('count of missing words: ', len(to_del))
        
for w in to_del:
    del vocab[w]
        
idx2word = {idx: word for idx, word in enumerate(['<eos>', '<unk>'] + list(vocab.keys()))}
word2idx = {word: idx for idx, word in enumerate(['<eos>', '<unk>'] + list(vocab.keys()))}
EOS, UNK = 0, 1

len(vocab), len(idx2word), len(word2idx)

word_embeddings = np.zeros((len(idx2word), 300))
for idx, word in idx2word.items():
    if idx == EOS:
        word_embeddings[idx] = wordvectors['eos']
    elif idx == UNK:
        word_embeddings[idx] = wordvectors['unk']
    else:
        word_embeddings[idx] = wordvectors[word]
# Out:
# [nltk_data] Downloading package punkt to /home/jeperez/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Avg. count of words per caption: 18.899161960284204
# Count of unique words:  11634
# missing word: toddles
# missing word: jellabiya
# missing word: gesticulates
# missing word: socket-outlet
# missing word: laundromatic
# missing word: outstretching
# missing word: peruke
# missing word: mtv-studio
# missing word: nba-playoff
# missing word: france/eu
# missing word: mewls
# missing word: tv-studio
# missing word: cacadoo
# missing word: air-kiss
# missing word: grining
# missing word: puppie
# missing word: twerking
# missing word: flic-flacs
# missing word: hoody
# missing word: rollick
# missing word: punchbag
# missing word: york-player
# missing word: bar-keeper
# missing word: overlarge
# missing word: muscly
# missing word: sidewards
# missing word: selfie
# missing word: one-move
# missing word: afflick
# missing word: fur-trimmed
# missing word: mid-court
# missing word: carooms
# missing word: face.
# missing word: martin-lewis
# missing word: break-dance
# missing word: head-butt
# missing word: venue..
# missing word: flip-phone
# missing word: spring-jumper
# missing word: back-flip
# missing word: azdrubel
# missing word: houston-cleveland
# missing word: re-cycling
# missing word: mime-game
# missing word: -a
# missing word: man-talks
# missing word: flute-like
# missing word: ancient-looking
# missing word: bad-mouthing
# missing word: break-dancing
# missing word: course..
# missing word: unfruitfully
# missing word: shirt/black
# missing word: nurse/caregiver
# missing word: unclasping
# missing word: red-trim
# missing word: chairs/sofas
# missing word: gray/white
# missing word: road/path
# missing word: imaichi
# missing word: large-mouthed
# missing word: oak-ten
# missing word: cheerleader-type
# missing word: long-tusked
# missing word: grey/white
# missing word: camera/mic
# missing word: facks
# missing word: mattress/foam
# missing word: inquiringly
# missing word: hurky
# missing word: skate-boarder
# missing word: high-five
# missing word: pyrographics
# missing word: face-time
# missing word: singing..
# missing word: baaing
# missing word: silver/black
# missing word: daces
# missing word: flower-covered
# missing word: bug-zapper
# missing word: team.
# missing word: gym..
# missing word: gray-haired
# missing word: on.d
# missing word: i-phone
# missing word: jello-looking
# missing word: blue/white
# missing word: dribbling-passing
# missing word: rods/crosses
# missing word: balloon-like
# missing word: oil-tank
# missing word: white/black
# missing word: /blue
# missing word: lightshow
# missing word: uniform-like
# missing word: 'hello
# missing word: cami-print
# missing word: hee-haw-ing
# missing word: arena..
# missing word: santa-style
# missing word: red/white
# missing word: howdies
# missing word: break-dancer
# missing word: around.
# missing word: yugyeom
# missing word: jacket/pants
# missing word: /red
# missing word: shorts/black
# missing word: cinder-block
# missing word: spring-board
# missing word: misblows
# missing word: singing/talking
# missing word: un-trained
# missing word: bed..
# missing word: earing
# missing word: sneakered
# missing word: broom/mop
# missing word: suit/costume
# missing word: cap/mask
# missing word: high-top
# missing word: military-like
# missing word: statue/award
# missing word: singing/dancing
# missing word: sound-over
# missing word: mouth-over
# missing word: tictac
# missing word: bating
# missing word: flour-laden
# missing word: chanting.
# missing word: fort-type
# missing word: jacket/white
# missing word: jacket/black
# missing word: gestures.
# missing word: hair/bangs
# missing word: motion..
# missing word: pyramid-type
# missing word: cheetah-like
# missing word: hip-hopping
# missing word: classroom-like
# missing word: same-colored
# missing word: nose-first
# missing word: half-swallows
# missing word: 'hit
# missing word: green/white
# missing word: thigh-high
# missing word: soccer-type
# missing word: monroe-style
# missing word: ledges/curbs
# missing word: embg
# missing word: coats/hoods
# missing word: crosslegged
# missing word: blue-shirted
# missing word: up..
# missing word: teeth-showing
# missing word: smiley-face
# missing word: bug-eyes
# missing word: room..
# missing word: re-play
# missing word: shirt/dress
# missing word: tan/black
# missing word: bulls-boston
# missing word: team/blue
# missing word: talking/rapping
# missing word: coffee/hot
# missing word: face/dark
# missing word: door..
# missing word: fire-crackers
# missing word: skirt/shorts
# missing word: mouth/big
# missing word: midi-top
# missing word: shirt/white
# missing word: over..
# missing word: shirt/faded
# missing word: ..
# missing word: acrobatics.
# missing word: lollypop
# missing word: instructions..
# missing word: fishtails
# missing word: play..
# missing word: usb-iphone
# missing word: light-show
# missing word: youngster..
# missing word: high-fiving
# missing word: 9stills
# missing word: snap-scissors
# missing word: brown-and-white
# missing word: same-sized
# missing word: fore-legs
# missing word: song-line
# missing word: slam-dunk
# missing word: singer/performer
# missing word: bee-like
# missing word: airport-like
# missing word: smiling.
# missing word: non-sense
# missing word: porta-potty
# missing word: table-mounted
# missing word: snow-board
# missing word: diving/throwing
# missing word: on-to-off-camera
# missing word: rooting-on
# missing word: pass-throw
# missing word: -up
# missing word: trying-out
# missing word: beiber
# missing word: foul-back
# missing word: paintballers
# missing word: box-fight
# missing word: mid-section
# missing word: summersaults
# missing word: back-flips
# missing word: -s
# missing word: swing-set
# missing word: summersault
# missing word: living/dining
# missing word: unbuttons
# missing word: reppin
# missing word: out-dribbles
# missing word: 'she
# missing word: visible..
# missing word: dining/living
# missing word: dancing.with
# missing word: unbuckles
# missing word: caution-tape
# missing word: yellow-taped
# missing word: boom-box
# missing word: make-shift
# missing word: over-the-head
# missing word: v-sign
# missing word: man-performer
# missing word: 'watch
# missing word: twin-bedded
# missing word: blue-topped
# missing word: black-jacketed
# missing word: ear-muffs
# missing word: leopard-skin
# missing word: thavasa
# missing word: passer-bye
# missing word: 'recovery
# missing word: gymtyme
# missing word: bat-man
# missing word: air-horn
# missing word: burnt-orange
# missing word: twerks
# missing word: stadium-style
# missing word: dust-covered
# missing word: many-colored
# missing word: tear-drops
# missing word: white-blonde
# missing word: ochimamiki
# missing word: man-colored
# missing word: pro-woman
# missing word: body-slamming
# missing word: topgear
# missing word: cotton-candy
# missing word: white-fleece
# missing word: grey-covered
# missing word: fair-like
# missing word: tie-dyed
# missing word: doggie-park
# missing word: loud-speaking
# missing word: pony-tailed
# missing word: boys..
# missing word: roles.one
# missing word: boxing..
# missing word: bang-bang-bang
# missing word: air-soft
# missing word: arm-locked
# missing word: autographic
# missing word: paddle-powered
# missing word: bump-like
# missing word: s___
# missing word: jacket-shirts
# missing word: color-changing
# missing word: gray-hired
# missing word: whoh
# missing word: t-line
# missing word: people..
# missing word: phones/cameras
# missing word: 2-bowled
# missing word: betway
# missing word: round.s
# missing word: black/silver
# missing word: time.s
# missing word: outdoors.
# missing word: long-wigged
# missing word: band.
# missing word: videoing
# missing word: torch-lit
# missing word: guinea-pig
# missing word: jives
# missing word: guitar..
# missing word: red/white/blue
# missing word: down..
# missing word: icy..
# missing word: floor..
# missing word: mild..
# missing word: falls.
# missing word: suv..
# missing word: coffee-like
# missing word: trowing
# missing word: sunsuit
# missing word: class.
# missing word: dr.phil
# missing word: other.in
# missing word: chest..
# missing word: shits
# missing word: vapes
# missing word: vape
# missing word: two.takes
# missing word: three-colored
# missing word: slip-and-slide
# missing word: mini-basketball
# missing word: him.
# missing word: picture-lined
# missing word: yellow-spotlighted
# missing word: card.which
# missing word: too-low
# missing word: dog/masks
# missing word: degrees..
# missing word: squirter
# missing word: towel.is
# missing word: stage.
# missing word: camera..
# missing word: green-patterned
# missing word: got7
# missing word: eating/drinking
# missing word: -white
# missing word: karate-like
# missing word: animal-costumed
# missing word: game.
# missing word: mouth-mounted
# missing word: xenoverse
# missing word: pink-clad
# missing word: questioningly
# missing word: kerchiefed
# missing word: manner.
# missing word: steps.down
# missing word: performance..
# missing word: hole..
# missing word: blow-dried
# missing word: selfies
# missing word: green-screen
# missing word: blackboard.showing
# missing word: body.
# missing word: 'snapchat
# missing word: tee-shirt
# missing word: red/orange
# missing word: badger-like
# missing word: marmet
# missing word: agame
# missing word: bakset
# missing word: /gliding
# missing word: frontwards
# missing word: tv.
# missing word: 'humping
# missing word: brexit
# missing word: floot
# missing word: mint-green
# missing word: kitchen/dinning
# missing word: silver-back
# missing word: gorila
# missing word: b.u.t
# missing word: co-contestant
# missing word: 'prancing
# missing word: high-stepping
# missing word: injured..
# missing word: combustable
# missing word: liquid-like
# missing word: hand-stands
# missing word: re-boarding
# missing word: cross-arm
# missing word: cross-leg
# missing word: tree.
# missing word: rabbit-like
# missing word: drivers\
# missing word: no2rouhani
# missing word: oves
# missing word: air-shocks
# missing word: rock/paper/scissors
# missing word: odds-evens
# missing word: robot-like
# missing word: black-curtained
# missing word: dark-suited
# missing word: flight-announcing
# missing word: half-opened
# missing word: .a
# missing word: on-lookers
# missing word: white-neon
# missing word: white-t-shirted
# missing word: segway=like
# missing word: redsocks
# missing word: long-sleeve
# missing word: brown-skinned
# missing word: blue-jean
# missing word: white-and-grey
# missing word: black-padded
# missing word: musses
# missing word: modelpress
# missing word: grey-and-white
# missing word: corgi-like
# missing word: arm-wrestle
# missing word: black-draped
# missing word: maroon-clad
# missing word: legs..
# missing word: elf-hats
# missing word: on..
# missing word: gold-trimmed
# missing word: door-jam
# missing word: long-blonde
# missing word: bikini-girl
# missing word: california-style
# missing word: neiman-marcus
# missing word: light-grey
# missing word: colorfully-patterned
# missing word: neck-ruff
# missing word: dachshund-like
# missing word: bronx-cheer
# missing word: blow-torch
# missing word: tacket
# missing word: mid-basketball
# missing word: snow-laden
# missing word: pink-trimmed
# missing word: duck-headed
# missing word: waist-pack
# missing word: noice
# missing word: yellow-sheeted
# missing word: light-filled
# missing word: reading-part
# missing word: freethrow
# missing word: coffee-colored
# missing word: teeshirt
# missing word: spreadeagled
# missing word: buldog
# missing word: hard-wood
# missing word: black-rimmed
# missing word: ferule
# missing word: asian-language
# missing word: black-ink
# missing word: many-storied
# missing word: close-cropped
# missing word: white-walled
# missing word: smart-phone
# missing word: duct-taped
# missing word: underbrim
# missing word: yellow-sleeveless
# missing word: teeshirts
# missing word: teamin
# missing word: white-shirted
# missing word: hot-dog-like
# missing word: tank-top
# missing word: brown-
# missing word: beatles-type
# missing word: 'he
# missing word: long-black
# missing word: neon-filled
# missing word: gold-streaked
# missing word: olive-skinned
# missing word: purple-shirted
# missing word: copa90
# missing word: fifr
# missing word: also-asian
# missing word: changing-colored
# missing word: sweat-panted
# missing word: holdig
# missing word: brown-wrapped
# missing word: yellow-jacketed
# missing word: sniggers
# missing word: istands
# missing word: act-out
# missing word: navy-colored
# missing word: cloth-clad
# missing word: head-in
# missing word: close-cut
# missing word: prophet-like
# missing word: kick-boxer
# missing word: ikes
# missing word: teal-colored
# missing word: tunic-length
# missing word: grey-striped
# missing word: face-to
# missing word: latino-looking
# missing word: bank-like
# missing word: chocolate-colored
# missing word: heavily-made-up
# missing word: tanktop
# missing word: koemi
# missing word: bts_jiemin
# missing word: grey-and
# missing word: public-area
# missing word: pepperment
# missing word: v-necked
# missing word: cap-sleeved
# missing word: hearse-like
# missing word: tree-surrounded
# missing word: person..
# missing word: oval-headed
# missing word: quizno
# missing word: wnrs
# missing word: wnpb
# missing word: barstoolsports
# missing word: fan-crowded
# missing word: dc29
# missing word: right-side-up
# missing word: blunging
# missing word: dark=haired
# missing word: 'let
# missing word: wide-topped
# missing word: re-lands
# missing word: malemute
# missing word: husky-like
# missing word: pink-and-white
# missing word: off..
# missing word: orienta
# missing word: uninterpretable
# missing word: chocker
# missing word: tri-tone
# missing word: mrz
# missing word: funyuns
# missing word: black-topped
# missing word: mop-headed
# missing word: half-ball
# missing word: clse
# missing word: marble-topped
# missing word: cheersport
# missing word: unscrews
# missing word: pastic
# missing word: winter-bare
# missing word: extralarge
# missing word: black-dressed
# missing word: yellow-painted
# missing word: blue-doored
# missing word: golf-course
# missing word: asian-alphabet
# missing word: white-topped
# missing word: re-throw
# missing word: green-shirted
# missing word: camera-like
# missing word: toy-sized
# missing word: c-lo
# missing word: tile-covered
# missing word: fold-over
# missing word: picture-time
# missing word: rummer
# missing word: blackops
# missing word: head-rest
# missing word: shaven-headed
# missing word: 'show
# missing word: black-coated
# missing word: red-nailed
# missing word: black-shirted
# missing word: stubbles
# missing word: white-clad
# missing word: green-glad
# missing word: convention-style
# missing word: food-court
# missing word: upper-floors
# missing word: branch-littered
# missing word: flokati
# missing word: glue-grey
# missing word: m-audio
# missing word: chair-desks
# missing word: doubled=over
# missing word: brain-freeze
# missing word: crack-head
# missing word: institutional-looking
# missing word: grey-bearded
# missing word: 'pizza
# missing word: lutting
# missing word: pretzel-shaped
# missing word: soccer-sized
# missing word: casemiro
# missing word: calisthenic
# missing word: grey-carpeted
# missing word: toy-covered
# missing word: playsuit
# missing word: black-rooted
# missing word: backwards-forwards
# missing word: 'happy
# missing word: 'selfie
# missing word: ofter
# missing word: blue-clad
# missing word: concrete-floored
# missing word: black-and-red
# missing word: guest-participation
# missing word: large-lensed
# missing word: 'spray
# missing word: attacher
# missing word: 'move
# missing word: window-lined
# missing word: orange-jacketed
# missing word: white-suited
# missing word: blue-lighted
# missing word: colapses
# missing word: smoothy
# missing word: t-shirted
# missing word: smoke/sparks
# missing word: manuvers
# missing word: white/red
# missing word: blue/red
# missing word: red/blue
# missing word: comopresses
# missing word: carseat
# missing word: wakens
# missing word: sprs
# missing word: anasian
# missing word: underbite
# missing word: wok=man
# missing word: rollaway
# missing word: hover-board
# missing word: belly-crawls
# missing word: dog-sized
# missing word: knells
# missing word: high-backed
# missing word: lift-gate
# missing word: raised-gate
# missing word: nocking
# missing word: magcon
# missing word: streetlamp
# missing word: .movements
# missing word: hiks
# missing word: swimmies
# missing word: top\y
# missing word: trows
# missing word: neglige
# missing word: head-butts
# missing word: multiperson
# missing word: grey-suited
# missing word: straw-covered
# missing word: *extra*
# missing word: cheted
# missing word: vidcon
# missing word: provoques
# missing word: missies
# missing word: timeother
# missing word: inner-tube
# missing word: threeasian
# missing word: one-hand
# missing word: smily
# missing word: time.
# missing word: red-carpeted
# missing word: sticklike
# missing word: orangutang
# missing word: cigaret
# missing word: things.
# missing word: arms0
# missing word: 2-bench
# missing word: mid-bite
# missing word: face-paint
# missing word: red-bearded
# missing word: fu*k
# missing word: osters
# missing word: bedrroom
# missing word: headphones/earbuds
# missing word: sh*t
# missing word: witch-like
# missing word: di*k
# missing word: under-lit
# missing word: white-framed
# missing word: spasming
# missing word: muthafukin
# missing word: hula-hoop
# missing word: housetops
# missing word: inner-tubes
# missing word: perfomer
# missing word: song.s
# missing word: ex-girl
# missing word: jaywalks
# missing word: vlive
# missing word: distance.
# missing word: red-striped
# missing word: shirrs
# missing word: skirt.s
# missing word: young-teen
# missing word: happy-face
# missing word: carousal
# missing word: paper-scissors-rock
# missing word: rock/scissor/paper
# missing word: cream-topped
# missing word: cartful
# missing word: w.coast
# missing word: oww
# missing word: si..
# missing word: fabe
# missing word: half-door
# missing word: somene
# missing word: dalls
# missing word: plataform
# missing word: peson
# missing word: rainbow-striped
# missing word: tippy-cup
# missing word: pipe-like
# missing word: chid
# missing word: dough-like
# missing word: dashcam
# missing word: six-packs
# missing word: time/
# missing word: safara
# missing word: inpark
# missing word: walkie-talkie-
# missing word: runon
# missing word: i-pad
# missing word: airpot
# missing word: redresses
# missing word: newsvideo
# missing word: pajamaed
# missing word: trolly
# missing word: skake
# missing word: band..
# missing word: water-fountains
# missing word: interwound
# missing word: uncarpeted
# missing word: suare
# missing word: ..someones
# missing word: posthole
# missing word: box/floor
# missing word: robot-girl
# missing word: puling
# missing word: surf-boarders
# missing word: burgundy-colored
# missing word: roller-skates
# missing word: raodway
# missing word: rvca
# missing word: locey
# missing word: preents
# missing word: rolll-up
# missing word: drink..
# missing word: spot-light
# missing word: high-fives
# missing word: f=group
# missing word: un-iced
# missing word: nippled
# missing word: *litter
# missing word: 2008*
# missing word: kiter
# missing word: mittened
# missing word: mid-ground
# missing word: marble-walled
# missing word: on/sit
# missing word: tonik
# missing word: copper-top
# missing word: by..
# missing word: hours.l
# missing word: underware
# missing word: sunshiney
# missing word: house-like
# missing word: umbrellaed
# missing word: goat-like
# missing word: rodie
# missing word: =s
# missing word: stopwar.ca
# missing word: animecentral
# missing word: dodge-em
# missing word: cowboy-hatted
# missing word: around..
# missing word: blue-sky
# missing word: nauticalia
# missing word: jakson
# missing word: multi-desk
# missing word: shews
# missing word: blond-looking
# missing word: lined-headdress
# missing word: ****
# missing word: *barbecues*
# missing word: thenh
# missing word: peahen
# missing word: traw
# missing word: well=mowed
# missing word: library-like
# missing word: repare
# missing word: parachuter
# missing word: balloon.
# count of missing words:  772

# %% [markdown]
# ### Determine POS-tagging vocabulary from train split

# %%
import nltk

pos_vocab = {}
pos_unique_words = {}
for cap in train_corpus:
    for tag in nltk.pos_tag(nltk.word_tokenize(cap.lower())):
        try:
            pos_vocab[tag[1]] += 1
            try: 
                pos_unique_words[tag[1]][tag[0]] += 1
            except:
                pos_unique_words[tag[1]][tag[0]] = 1
        except:
            pos_vocab[tag[1]] = 1
            pos_unique_words[tag[1]] = {tag[0]: 1}

print('Unique words per tag:')
print('\n'.join([f' {k}:\t{len(words)}' for k, words in pos_unique_words.items()]))
            
idx2pos = {idx: tag for idx, tag in enumerate(['eos', 'unk'] + list(pos_vocab.keys()))}
pos2idx = {tag: idx for idx, tag in enumerate(['eos', 'unk'] + list(pos_vocab.keys()))}
EOS, UNK = 0, 1
print(len(idx2pos))
# Out:
# Unique words per tag:
#  DT:	23
#  NN:	5352
#  VBZ:	939
#  IN:	126
#  PRP$:	7
#  ,:	1
#  CD:	104
#  NNS:	2165
#  VBP:	740
#  JJ:	2816
#  VBG:	1036
#  TO:	2
#  VB:	941
#  RP:	28
#  .:	3
#  CC:	19
#  RB:	522
#  POS:	4
#  PRP:	24
#  VBN:	767
#  VBD:	502
#  WRB:	7
#  WDT:	6
#  (:	1
#  ):	1
#  PDT:	14
#  JJR:	52
#  WP:	7
#  MD:	14
#  ``:	1
#  '':	5
#  WP$:	1
#  JJS:	16
#  ::	5
#  UH:	3
#  EX:	2
#  #:	1
#  FW:	16
#  RBR:	16
#  NNP:	12
#  $:	2
#  RBS:	1
# 44

# %% [markdown]
# ### Determine Universal POS-tagging from train split

# %%
import nltk
nltk.download('universal_tagset')

upos_vocab = {}
upos_unique_words = {}
for cap in train_corpus:
    for tag in nltk.pos_tag(nltk.word_tokenize(cap.lower()), tagset='universal'):
        try:
            upos_vocab[tag[1]] += 1
            try: 
                upos_unique_words[tag[1]][tag[0]] += 1
            except:
                upos_unique_words[tag[1]][tag[0]] = 1
        except:
            upos_vocab[tag[1]] = 1
            upos_unique_words[tag[1]] = {tag[0]: 1}

print('Unique words per universal tag:')
print('\n'.join([f' {k}:\t{len(words)}' for k, words in upos_unique_words.items()]))
            
idx2upos = {idx: word for idx, word in enumerate(['eos', 'unk'] + list(upos_vocab.keys()))}
upos2idx = {word: idx for idx, word in enumerate(['eos', 'unk'] + list(upos_vocab.keys()))}
print(len(idx2upos))
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /home/jeperez/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# Unique words per universal tag:
#  DET:	40
#  NOUN:	7316
#  VERB:	4038
#  ADP:	126
#  PRON:	38
#  .:	20
#  NUM:	104
#  ADJ:	2878
#  PRT:	34
#  CONJ:	19
#  ADV:	542
#  X:	19
# 14

# %% [markdown]
# ### Generate ground-truth references files

# %%
with open('../results/TRECVID-2020_val_references.txt', 'w') as f:
    for vidx, cap in zip(valid_vidxs, valid_corpus):
        f.write('{}\t{}\n'.format(vidx, cap))

# %% [markdown]
# #### test reference files, after the ground-truth was released

# %%
import json
with open('../../../data/TRECVID/tv2020/test/Description_Generation_Groundtruth/vtt.cider.gt.json') as f:
    gt = json.load(f)

with open('../results/TRECVID-2020_test_references.txt', 'w') as f:
    for row in gt:
        f.write('{}\t{}\n'.format(row['image_id'], row['caption']))

# %% [markdown]
# ### Generate corpus.pkl file

# %%
import pickle

train_corpus_widxs = [[word2idx[w] if w in vocab else UNK for w in nltk.word_tokenize(cap.lower())] + [EOS] for cap in train_corpus]
valid_corpus_widxs = [[word2idx[w] if w in vocab else UNK for w in nltk.word_tokenize(cap.lower())] + [EOS] for cap in valid_corpus]

train_corpus_pidxs = [[pos2idx[w[1]] if w[1] in pos_vocab else UNK for w in nltk.pos_tag(nltk.word_tokenize(cap.lower()))] + [EOS] for cap in train_corpus]
valid_corpus_pidxs = [[pos2idx[w[1]] if w[1] in pos_vocab else UNK for w in nltk.pos_tag(nltk.word_tokenize(cap.lower()))] + [EOS] for cap in valid_corpus]

assert len(train_corpus_widxs) == len(train_vidxs) and len(train_vidxs) == len(train_corpus_pidxs) and len(train_vidxs) == len(train_corpus), f'{len(train_vidxs)}, {len(train_corpus_widxs)}, {len(train_corpus_pidxs)}, {len(train_corpus)}'
assert len(valid_corpus_widxs) == len(valid_vidxs) and len(valid_vidxs) == len(valid_corpus_pidxs) and len(valid_vidxs) == len(valid_corpus), f'{len(valid_vidxs)}, {len(valid_corpus_widxs)}, {len(valid_corpus_pidxs)}, {len(valid_corpus)}'

train_data = [train_corpus_widxs, train_vidxs, train_corpus_pidxs, train_corpus]
valid_data = [valid_corpus_widxs, valid_vidxs, valid_corpus_pidxs, valid_corpus]

with open('../../../data/TRECVID/tv2020/trecvid_tv2020_corpus_pos.pkl', 'wb') as outfile:
    pickle.dump([train_data, valid_data, None, vocab, idx2word, word_embeddings, idx2pos], outfile)

# %%
print(train_vidxs[0])
print(train_corpus[0])
nltk.pos_tag(nltk.word_tokenize(train_corpus[0]))
# Out:
# 0
# a man sings in a car
# [('a', 'DT'),
#  ('man', 'NN'),
#  ('sings', 'VBZ'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('car', 'NN')]

# %%
print(valid_vidxs[0])
print(valid_corpus[0])
valid_corpus_pidxs[0]
# Out:
# 6
# a man is scared by a picture of a boy on a mirror in a bathroom
# [2, 3, 4, 21, 5, 2, 3, 5, 2, 3, 5, 2, 3, 5, 2, 3, 0]
